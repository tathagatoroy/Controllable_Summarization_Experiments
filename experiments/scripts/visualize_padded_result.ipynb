# %%
import matplotlib.pyplot as plt
import tqdm
import numpy as np
import os
import sys
import time
import json
import pprint

# %%
result_json = "../combined_result.json"
print(os.path.exists(result_json))
json_data = json.load(open(result_json))
# Out:
# True

# %%
pprint.pprint(json_data)
# Out:
# {'/scratch/tathagato/experiment_outputs/extractiveness_extractiveness_0.0001_checkpoint-1000_extractiveness.json': {'attribute': 'extractiveness',
#                                                                                                                     'result': {'fully': {'cer': 0.8107779358580318,
#                                                                                                                                          'gold_f_score': 0.92077,
#                                                                                                                                          'num_examples': 1,
#                                                                                                                                          'prediction_coverage': 0.8235294117647058,
#                                                                                                                                          'prediction_density': 1.607843137254902,
# ...
